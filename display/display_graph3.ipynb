# %% [markdown]
# # Graph 3 Algorithm Trace Tables
#
# Run the cells below to render matplotlib table images for Dijkstra, Bellman-Ford, and Floyd-Warshall.

# %%
from pathlib import Path
import importlib
import sys

project_root = Path.cwd()
if project_root.name == "display":
    project_root = project_root.parent

if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

import display.display_tool as display_tool
import display.tools.plot_bellman_ford as bellman_plot
import display.tools.plot_dijkstra as dijkstra_plot
import display.tools.plot_floyd_warshall as floyd_plot
# from algo.dijkstra import dijkstra, reconstruct_path, format_path
from graph.graph3 import GRAPH_3

import sys
import os

project_root = os.path.abspath("..\\..")
sys.path.append(project_root)


plot_bellman_ford_trace = bellman_plot.plot_bellman_ford_trace
plot_dijkstra_trace = dijkstra_plot.plot_dijkstra_trace
plot_floyd_warshall_trace = floyd_plot.plot_floyd_warshall_trace

# %% [markdown]
# ## Create initial starting point

# %%
START = "a"

# %% [markdown]
# ## Dijkstra

# %%
plot_dijkstra_trace(GRAPH_3, START);
# Out:
# a(0) -(2)-> b: min(2, infinity) -> choose 2 so it will be a(0) -(2)-> b(2)
# a(0) -(4)-> c: min(4, infinity) -> choose 4 so it will be a(0) -(4)-> c(4)
# a(0) -(1)-> d: min(1, infinity) -> choose 1 so it will be a(0) -(1)-> d(1)
# d(1) -(5)-> f: min(6, infinity) -> choose 6 so it will be a(0) -(1)-> d(1) -(5)-> f(6)
# d(1) -(4)-> g: min(5, infinity) -> choose 5 so it will be a(0) -(1)-> d(1) -(4)-> g(5)
# b(2) -(3)-> c: min(5, 4) -> no update
# b(2) -(1)-> e: min(3, infinity) -> choose 3 so it will be a(0) -(2)-> b(2) -(1)-> e(3)
# e(3) -(2)-> c: min(5, 4) -> no update
# e(3) -(3)-> h: min(6, infinity) -> choose 6 so it will be a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6)
# c(4) -(2)-> f: min(6, 6) -> no update
# g(5) -(3)-> f: min(8, 6) -> no update
# g(5) -(2)-> k: min(7, infinity) -> choose 7 so it will be a(0) -(1)-> d(1) -(4)-> g(5) -(2)-> k(7)
# f(6) -(3)-> h: min(9, 6) -> no update
# f(6) -(2)-> i: min(8, infinity) -> choose 8 so it will be a(0) -(1)-> d(1) -(5)-> f(6) -(2)-> i(8)
# f(6) -(4)-> j: min(10, infinity) -> choose 10 so it will be a(0) -(1)-> d(1) -(5)-> f(6) -(4)-> j(10)
# h(6) -(1)-> l: min(7, infinity) -> choose 7 so it will be a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7)
# h(6) -(8)-> o: min(14, infinity) -> choose 14 so it will be a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(8)-> o(14)
# k(7) -(6)-> j: min(13, 10) -> no update
# k(7) -(4)-> n: min(11, infinity) -> choose 11 so it will be a(0) -(1)-> d(1) -(4)-> g(5) -(2)-> k(7) -(4)-> n(11)
# k(7) -(2)-> r: min(9, infinity) -> choose 9 so it will be a(0) -(1)-> d(1) -(4)-> g(5) -(2)-> k(7) -(2)-> r(9)
# l(7) -(3)-> i: min(10, 8) -> no update
# l(7) -(3)-> m: min(10, infinity) -> choose 10 so it will be a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7) -(3)-> m(10)
# l(7) -(6)-> o: min(13, 14) -> choose 13 so it will be a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7) -(6)-> o(13)
# i(8) -(3)-> j: min(11, 10) -> no update
# i(8) -(2)-> m: min(10, 10) -> no update
# r(9) -(1)-> n: min(10, 11) -> choose 10 so it will be a(0) -(1)-> d(1) -(4)-> g(5) -(2)-> k(7) -(2)-> r(9) -(1)-> n(10)
# r(9) -(8)-> q: min(17, infinity) -> choose 17 so it will be a(0) -(1)-> d(1) -(4)-> g(5) -(2)-> k(7) -(2)-> r(9) -(8)-> q(17)
# r(9) -(5)-> t: min(14, infinity) -> choose 14 so it will be a(0) -(1)-> d(1) -(4)-> g(5) -(2)-> k(7) -(2)-> r(9) -(5)-> t(14)
# j(10) -(6)-> m: min(16, 10) -> no update
# j(10) -(3)-> n: min(13, 10) -> no update
# m(10) -(5)-> n: min(15, 10) -> no update
# m(10) -(4)-> o: min(14, 13) -> no update
# m(10) -(2)-> p: min(12, infinity) -> choose 12 so it will be a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7) -(3)-> m(10) -(2)-> p(12)
# n(10) -(2)-> q: min(12, 17) -> choose 12 so it will be a(0) -(1)-> d(1) -(4)-> g(5) -(2)-> k(7) -(2)-> r(9) -(1)-> n(10) -(2)-> q(12)
# p(12) -(2)-> o: min(14, 13) -> no update
# p(12) -(1)-> q: min(13, 12) -> no update
# p(12) -(2)-> s: min(14, infinity) -> choose 14 so it will be a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7) -(3)-> m(10) -(2)-> p(12) -(2)-> s(14)
# p(12) -(1)-> t: min(13, 14) -> choose 13 so it will be a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7) -(3)-> m(10) -(2)-> p(12) -(1)-> t(13)
# q(12) -(3)-> t: min(15, 13) -> no update
# o(13) -(6)-> s: min(19, 14) -> no update
# t(13) -(8)-> z: min(21, infinity) -> choose 21 so it will be a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7) -(3)-> m(10) -(2)-> p(12) -(1)-> t(13) -(8)-> z(21)
# s(14) -(2)-> z: min(16, 21) -> choose 16 so it will be a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7) -(3)-> m(10) -(2)-> p(12) -(2)-> s(14) -(2)-> z(16)
#
# ==============================
# BEST PATHS FROM START:
# ==============================
# a -> b: a(0) -(2)-> b(2)
# a -> c: a(0) -(4)-> c(4)
# a -> d: a(0) -(1)-> d(1)
# a -> e: a(0) -(2)-> b(2) -(1)-> e(3)
# a -> f: a(0) -(1)-> d(1) -(5)-> f(6)
# a -> g: a(0) -(1)-> d(1) -(4)-> g(5)
# a -> h: a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6)
# a -> i: a(0) -(1)-> d(1) -(5)-> f(6) -(2)-> i(8)
# a -> j: a(0) -(1)-> d(1) -(5)-> f(6) -(4)-> j(10)
# a -> k: a(0) -(1)-> d(1) -(4)-> g(5) -(2)-> k(7)
# a -> l: a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7)
# a -> m: a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7) -(3)-> m(10)
# a -> n: a(0) -(1)-> d(1) -(4)-> g(5) -(2)-> k(7) -(2)-> r(9) -(1)-> n(10)
# a -> o: a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7) -(6)-> o(13)
# a -> p: a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7) -(3)-> m(10) -(2)-> p(12)
# a -> q: a(0) -(1)-> d(1) -(4)-> g(5) -(2)-> k(7) -(2)-> r(9) -(1)-> n(10) -(2)-> q(12)
# a -> r: a(0) -(1)-> d(1) -(4)-> g(5) -(2)-> k(7) -(2)-> r(9)
# a -> s: a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7) -(3)-> m(10) -(2)-> p(12) -(2)-> s(14)
# a -> t: a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7) -(3)-> m(10) -(2)-> p(12) -(1)-> t(13)
# a -> z: a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7) -(3)-> m(10) -(2)-> p(12) -(2)-> s(14) -(2)-> z(16)

# %% [markdown]
# ## Bellman-Ford

# %%
plot_bellman_ford_trace(GRAPH_3, START);
# Out:
# ============================================================
# BELLMAN-FORD ALGORITHM
# ============================================================
# Total vertices = 21
# Maximum iterations = V - 1 = 21 - 1 = 20
#
# Graph has NO negative edges.
# => Negative cycle is impossible.
#
# ============================================================
# ITERATION 1
# ============================================================
# (a, b) : a(0) -(2)-> b : min(2, inf) -> UPDATE
# (a, c) : a(0) -(4)-> c : min(4, inf) -> UPDATE
# (a, d) : a(0) -(1)-> d : min(1, inf) -> UPDATE
# (b, a) : b(2) -(2)-> a : min(4, 0) -> NO UPDATE
# (b, c) : b(2) -(3)-> c : min(5, 4) -> NO UPDATE
# (b, e) : b(2) -(1)-> e : min(3, inf) -> UPDATE
# (c, a) : c(4) -(4)-> a : min(8, 0) -> NO UPDATE
# (c, b) : c(4) -(3)-> b : min(7, 2) -> NO UPDATE
# (c, e) : c(4) -(2)-> e : min(6, 3) -> NO UPDATE
# (c, f) : c(4) -(2)-> f : min(6, inf) -> UPDATE
# (d, a) : d(1) -(1)-> a : min(2, 0) -> NO UPDATE
# (d, f) : d(1) -(5)-> f : min(6, 6) -> NO UPDATE
# (d, g) : d(1) -(4)-> g : min(5, inf) -> UPDATE
# (e, b) : e(3) -(1)-> b : min(4, 2) -> NO UPDATE
# (e, c) : e(3) -(2)-> c : min(5, 4) -> NO UPDATE
# (e, h) : e(3) -(3)-> h : min(6, inf) -> UPDATE
# (f, c) : f(6) -(2)-> c : min(8, 4) -> NO UPDATE
# (f, d) : f(6) -(5)-> d : min(11, 1) -> NO UPDATE
# (f, g) : f(6) -(3)-> g : min(9, 5) -> NO UPDATE
# (f, h) : f(6) -(3)-> h : min(9, 6) -> NO UPDATE
# (f, i) : f(6) -(2)-> i : min(8, inf) -> UPDATE
# (f, j) : f(6) -(4)-> j : min(10, inf) -> UPDATE
# (g, d) : g(5) -(4)-> d : min(9, 1) -> NO UPDATE
# (g, f) : g(5) -(3)-> f : min(8, 6) -> NO UPDATE
# (g, k) : g(5) -(2)-> k : min(7, inf) -> UPDATE
# (h, e) : h(6) -(3)-> e : min(9, 3) -> NO UPDATE
# (h, f) : h(6) -(3)-> f : min(9, 6) -> NO UPDATE
# (h, l) : h(6) -(1)-> l : min(7, inf) -> UPDATE
# (h, o) : h(6) -(8)-> o : min(14, inf) -> UPDATE
# (i, f) : i(8) -(2)-> f : min(10, 6) -> NO UPDATE
# (i, j) : i(8) -(3)-> j : min(11, 10) -> NO UPDATE
# (i, l) : i(8) -(3)-> l : min(11, 7) -> NO UPDATE
# (i, m) : i(8) -(2)-> m : min(10, inf) -> UPDATE
# (j, f) : j(10) -(4)-> f : min(14, 6) -> NO UPDATE
# (j, i) : j(10) -(3)-> i : min(13, 8) -> NO UPDATE
# (j, k) : j(10) -(6)-> k : min(16, 7) -> NO UPDATE
# (j, m) : j(10) -(6)-> m : min(16, 10) -> NO UPDATE
# (j, n) : j(10) -(3)-> n : min(13, inf) -> UPDATE
# (k, g) : k(7) -(2)-> g : min(9, 5) -> NO UPDATE
# (k, j) : k(7) -(6)-> j : min(13, 10) -> NO UPDATE
# (k, n) : k(7) -(4)-> n : min(11, 13) -> UPDATE
# (k, r) : k(7) -(2)-> r : min(9, inf) -> UPDATE
# (l, h) : l(7) -(1)-> h : min(8, 6) -> NO UPDATE
# (l, i) : l(7) -(3)-> i : min(10, 8) -> NO UPDATE
# (l, m) : l(7) -(3)-> m : min(10, 10) -> NO UPDATE
# (l, o) : l(7) -(6)-> o : min(13, 14) -> UPDATE
# (m, i) : m(10) -(2)-> i : min(12, 8) -> NO UPDATE
# (m, j) : m(10) -(6)-> j : min(16, 10) -> NO UPDATE
# (m, l) : m(10) -(3)-> l : min(13, 7) -> NO UPDATE
# (m, n) : m(10) -(5)-> n : min(15, 11) -> NO UPDATE
# (m, o) : m(10) -(4)-> o : min(14, 13) -> NO UPDATE
# (m, p) : m(10) -(2)-> p : min(12, inf) -> UPDATE
# (n, j) : n(11) -(3)-> j : min(14, 10) -> NO UPDATE
# (n, k) : n(11) -(4)-> k : min(15, 7) -> NO UPDATE
# (n, m) : n(11) -(5)-> m : min(16, 10) -> NO UPDATE
# (n, q) : n(11) -(2)-> q : min(13, inf) -> UPDATE
# (n, r) : n(11) -(1)-> r : min(12, 9) -> NO UPDATE
# (o, h) : o(13) -(8)-> h : min(21, 6) -> NO UPDATE
# (o, l) : o(13) -(6)-> l : min(19, 7) -> NO UPDATE
# (o, m) : o(13) -(4)-> m : min(17, 10) -> NO UPDATE
# (o, p) : o(13) -(2)-> p : min(15, 12) -> NO UPDATE
# (o, s) : o(13) -(6)-> s : min(19, inf) -> UPDATE
# (p, m) : p(12) -(2)-> m : min(14, 10) -> NO UPDATE
# (p, o) : p(12) -(2)-> o : min(14, 13) -> NO UPDATE
# (p, q) : p(12) -(1)-> q : min(13, 13) -> NO UPDATE
# (p, s) : p(12) -(2)-> s : min(14, 19) -> UPDATE
# (p, t) : p(12) -(1)-> t : min(13, inf) -> UPDATE
# (q, n) : q(13) -(2)-> n : min(15, 11) -> NO UPDATE
# (q, p) : q(13) -(1)-> p : min(14, 12) -> NO UPDATE
# (q, r) : q(13) -(8)-> r : min(21, 9) -> NO UPDATE
# (q, t) : q(13) -(3)-> t : min(16, 13) -> NO UPDATE
# (r, k) : r(9) -(2)-> k : min(11, 7) -> NO UPDATE
# (r, n) : r(9) -(1)-> n : min(10, 11) -> UPDATE
# (r, q) : r(9) -(8)-> q : min(17, 13) -> NO UPDATE
# (r, t) : r(9) -(5)-> t : min(14, 13) -> NO UPDATE
# (s, o) : s(14) -(6)-> o : min(20, 13) -> NO UPDATE
# (s, p) : s(14) -(2)-> p : min(16, 12) -> NO UPDATE
# (s, z) : s(14) -(2)-> z : min(16, inf) -> UPDATE
# (t, p) : t(13) -(1)-> p : min(14, 12) -> NO UPDATE
# (t, q) : t(13) -(3)-> q : min(16, 13) -> NO UPDATE
# (t, r) : t(13) -(5)-> r : min(18, 9) -> NO UPDATE
# (t, z) : t(13) -(8)-> z : min(21, 16) -> NO UPDATE
# (z, s) : z(16) -(2)-> s : min(18, 14) -> NO UPDATE
# (z, t) : z(16) -(8)-> t : min(24, 13) -> NO UPDATE
#
# ============================================================
# ITERATION 2
# ============================================================
# (a, b) : a(0) -(2)-> b : min(2, 2) -> NO UPDATE
# (a, c) : a(0) -(4)-> c : min(4, 4) -> NO UPDATE
# (a, d) : a(0) -(1)-> d : min(1, 1) -> NO UPDATE
# (b, a) : b(2) -(2)-> a : min(4, 0) -> NO UPDATE
# (b, c) : b(2) -(3)-> c : min(5, 4) -> NO UPDATE
# (b, e) : b(2) -(1)-> e : min(3, 3) -> NO UPDATE
# (c, a) : c(4) -(4)-> a : min(8, 0) -> NO UPDATE
# (c, b) : c(4) -(3)-> b : min(7, 2) -> NO UPDATE
# (c, e) : c(4) -(2)-> e : min(6, 3) -> NO UPDATE
# (c, f) : c(4) -(2)-> f : min(6, 6) -> NO UPDATE
# (d, a) : d(1) -(1)-> a : min(2, 0) -> NO UPDATE
# (d, f) : d(1) -(5)-> f : min(6, 6) -> NO UPDATE
# (d, g) : d(1) -(4)-> g : min(5, 5) -> NO UPDATE
# (e, b) : e(3) -(1)-> b : min(4, 2) -> NO UPDATE
# (e, c) : e(3) -(2)-> c : min(5, 4) -> NO UPDATE
# (e, h) : e(3) -(3)-> h : min(6, 6) -> NO UPDATE
# (f, c) : f(6) -(2)-> c : min(8, 4) -> NO UPDATE
# (f, d) : f(6) -(5)-> d : min(11, 1) -> NO UPDATE
# (f, g) : f(6) -(3)-> g : min(9, 5) -> NO UPDATE
# (f, h) : f(6) -(3)-> h : min(9, 6) -> NO UPDATE
# (f, i) : f(6) -(2)-> i : min(8, 8) -> NO UPDATE
# (f, j) : f(6) -(4)-> j : min(10, 10) -> NO UPDATE
# (g, d) : g(5) -(4)-> d : min(9, 1) -> NO UPDATE
# (g, f) : g(5) -(3)-> f : min(8, 6) -> NO UPDATE
# (g, k) : g(5) -(2)-> k : min(7, 7) -> NO UPDATE
# (h, e) : h(6) -(3)-> e : min(9, 3) -> NO UPDATE
# (h, f) : h(6) -(3)-> f : min(9, 6) -> NO UPDATE
# (h, l) : h(6) -(1)-> l : min(7, 7) -> NO UPDATE
# (h, o) : h(6) -(8)-> o : min(14, 13) -> NO UPDATE
# (i, f) : i(8) -(2)-> f : min(10, 6) -> NO UPDATE
# (i, j) : i(8) -(3)-> j : min(11, 10) -> NO UPDATE
# (i, l) : i(8) -(3)-> l : min(11, 7) -> NO UPDATE
# (i, m) : i(8) -(2)-> m : min(10, 10) -> NO UPDATE
# (j, f) : j(10) -(4)-> f : min(14, 6) -> NO UPDATE
# (j, i) : j(10) -(3)-> i : min(13, 8) -> NO UPDATE
# (j, k) : j(10) -(6)-> k : min(16, 7) -> NO UPDATE
# (j, m) : j(10) -(6)-> m : min(16, 10) -> NO UPDATE
# (j, n) : j(10) -(3)-> n : min(13, 10) -> NO UPDATE
# (k, g) : k(7) -(2)-> g : min(9, 5) -> NO UPDATE
# (k, j) : k(7) -(6)-> j : min(13, 10) -> NO UPDATE
# (k, n) : k(7) -(4)-> n : min(11, 10) -> NO UPDATE
# (k, r) : k(7) -(2)-> r : min(9, 9) -> NO UPDATE
# (l, h) : l(7) -(1)-> h : min(8, 6) -> NO UPDATE
# (l, i) : l(7) -(3)-> i : min(10, 8) -> NO UPDATE
# (l, m) : l(7) -(3)-> m : min(10, 10) -> NO UPDATE
# (l, o) : l(7) -(6)-> o : min(13, 13) -> NO UPDATE
# (m, i) : m(10) -(2)-> i : min(12, 8) -> NO UPDATE
# (m, j) : m(10) -(6)-> j : min(16, 10) -> NO UPDATE
# (m, l) : m(10) -(3)-> l : min(13, 7) -> NO UPDATE
# (m, n) : m(10) -(5)-> n : min(15, 10) -> NO UPDATE
# (m, o) : m(10) -(4)-> o : min(14, 13) -> NO UPDATE
# (m, p) : m(10) -(2)-> p : min(12, 12) -> NO UPDATE
# (n, j) : n(10) -(3)-> j : min(13, 10) -> NO UPDATE
# (n, k) : n(10) -(4)-> k : min(14, 7) -> NO UPDATE
# (n, m) : n(10) -(5)-> m : min(15, 10) -> NO UPDATE
# (n, q) : n(10) -(2)-> q : min(12, 13) -> UPDATE
# (n, r) : n(10) -(1)-> r : min(11, 9) -> NO UPDATE
# (o, h) : o(13) -(8)-> h : min(21, 6) -> NO UPDATE
# (o, l) : o(13) -(6)-> l : min(19, 7) -> NO UPDATE
# (o, m) : o(13) -(4)-> m : min(17, 10) -> NO UPDATE
# (o, p) : o(13) -(2)-> p : min(15, 12) -> NO UPDATE
# (o, s) : o(13) -(6)-> s : min(19, 14) -> NO UPDATE
# (p, m) : p(12) -(2)-> m : min(14, 10) -> NO UPDATE
# (p, o) : p(12) -(2)-> o : min(14, 13) -> NO UPDATE
# (p, q) : p(12) -(1)-> q : min(13, 12) -> NO UPDATE
# (p, s) : p(12) -(2)-> s : min(14, 14) -> NO UPDATE
# (p, t) : p(12) -(1)-> t : min(13, 13) -> NO UPDATE
# (q, n) : q(12) -(2)-> n : min(14, 10) -> NO UPDATE
# (q, p) : q(12) -(1)-> p : min(13, 12) -> NO UPDATE
# (q, r) : q(12) -(8)-> r : min(20, 9) -> NO UPDATE
# (q, t) : q(12) -(3)-> t : min(15, 13) -> NO UPDATE
# (r, k) : r(9) -(2)-> k : min(11, 7) -> NO UPDATE
# (r, n) : r(9) -(1)-> n : min(10, 10) -> NO UPDATE
# (r, q) : r(9) -(8)-> q : min(17, 12) -> NO UPDATE
# (r, t) : r(9) -(5)-> t : min(14, 13) -> NO UPDATE
# (s, o) : s(14) -(6)-> o : min(20, 13) -> NO UPDATE
# (s, p) : s(14) -(2)-> p : min(16, 12) -> NO UPDATE
# (s, z) : s(14) -(2)-> z : min(16, 16) -> NO UPDATE
# (t, p) : t(13) -(1)-> p : min(14, 12) -> NO UPDATE
# (t, q) : t(13) -(3)-> q : min(16, 12) -> NO UPDATE
# (t, r) : t(13) -(5)-> r : min(18, 9) -> NO UPDATE
# (t, z) : t(13) -(8)-> z : min(21, 16) -> NO UPDATE
# (z, s) : z(16) -(2)-> s : min(18, 14) -> NO UPDATE
# (z, t) : z(16) -(8)-> t : min(24, 13) -> NO UPDATE
#
# ============================================================
# ITERATION 3
# ============================================================
# (a, b) : a(0) -(2)-> b : min(2, 2) -> NO UPDATE
# (a, c) : a(0) -(4)-> c : min(4, 4) -> NO UPDATE
# (a, d) : a(0) -(1)-> d : min(1, 1) -> NO UPDATE
# (b, a) : b(2) -(2)-> a : min(4, 0) -> NO UPDATE
# (b, c) : b(2) -(3)-> c : min(5, 4) -> NO UPDATE
# (b, e) : b(2) -(1)-> e : min(3, 3) -> NO UPDATE
# (c, a) : c(4) -(4)-> a : min(8, 0) -> NO UPDATE
# (c, b) : c(4) -(3)-> b : min(7, 2) -> NO UPDATE
# (c, e) : c(4) -(2)-> e : min(6, 3) -> NO UPDATE
# (c, f) : c(4) -(2)-> f : min(6, 6) -> NO UPDATE
# (d, a) : d(1) -(1)-> a : min(2, 0) -> NO UPDATE
# (d, f) : d(1) -(5)-> f : min(6, 6) -> NO UPDATE
# (d, g) : d(1) -(4)-> g : min(5, 5) -> NO UPDATE
# (e, b) : e(3) -(1)-> b : min(4, 2) -> NO UPDATE
# (e, c) : e(3) -(2)-> c : min(5, 4) -> NO UPDATE
# (e, h) : e(3) -(3)-> h : min(6, 6) -> NO UPDATE
# (f, c) : f(6) -(2)-> c : min(8, 4) -> NO UPDATE
# (f, d) : f(6) -(5)-> d : min(11, 1) -> NO UPDATE
# (f, g) : f(6) -(3)-> g : min(9, 5) -> NO UPDATE
# (f, h) : f(6) -(3)-> h : min(9, 6) -> NO UPDATE
# (f, i) : f(6) -(2)-> i : min(8, 8) -> NO UPDATE
# (f, j) : f(6) -(4)-> j : min(10, 10) -> NO UPDATE
# (g, d) : g(5) -(4)-> d : min(9, 1) -> NO UPDATE
# (g, f) : g(5) -(3)-> f : min(8, 6) -> NO UPDATE
# (g, k) : g(5) -(2)-> k : min(7, 7) -> NO UPDATE
# (h, e) : h(6) -(3)-> e : min(9, 3) -> NO UPDATE
# (h, f) : h(6) -(3)-> f : min(9, 6) -> NO UPDATE
# (h, l) : h(6) -(1)-> l : min(7, 7) -> NO UPDATE
# (h, o) : h(6) -(8)-> o : min(14, 13) -> NO UPDATE
# (i, f) : i(8) -(2)-> f : min(10, 6) -> NO UPDATE
# (i, j) : i(8) -(3)-> j : min(11, 10) -> NO UPDATE
# (i, l) : i(8) -(3)-> l : min(11, 7) -> NO UPDATE
# (i, m) : i(8) -(2)-> m : min(10, 10) -> NO UPDATE
# (j, f) : j(10) -(4)-> f : min(14, 6) -> NO UPDATE
# (j, i) : j(10) -(3)-> i : min(13, 8) -> NO UPDATE
# (j, k) : j(10) -(6)-> k : min(16, 7) -> NO UPDATE
# (j, m) : j(10) -(6)-> m : min(16, 10) -> NO UPDATE
# (j, n) : j(10) -(3)-> n : min(13, 10) -> NO UPDATE
# (k, g) : k(7) -(2)-> g : min(9, 5) -> NO UPDATE
# (k, j) : k(7) -(6)-> j : min(13, 10) -> NO UPDATE
# (k, n) : k(7) -(4)-> n : min(11, 10) -> NO UPDATE
# (k, r) : k(7) -(2)-> r : min(9, 9) -> NO UPDATE
# (l, h) : l(7) -(1)-> h : min(8, 6) -> NO UPDATE
# (l, i) : l(7) -(3)-> i : min(10, 8) -> NO UPDATE
# (l, m) : l(7) -(3)-> m : min(10, 10) -> NO UPDATE
# (l, o) : l(7) -(6)-> o : min(13, 13) -> NO UPDATE
# (m, i) : m(10) -(2)-> i : min(12, 8) -> NO UPDATE
# (m, j) : m(10) -(6)-> j : min(16, 10) -> NO UPDATE
# (m, l) : m(10) -(3)-> l : min(13, 7) -> NO UPDATE
# (m, n) : m(10) -(5)-> n : min(15, 10) -> NO UPDATE
# (m, o) : m(10) -(4)-> o : min(14, 13) -> NO UPDATE
# (m, p) : m(10) -(2)-> p : min(12, 12) -> NO UPDATE
# (n, j) : n(10) -(3)-> j : min(13, 10) -> NO UPDATE
# (n, k) : n(10) -(4)-> k : min(14, 7) -> NO UPDATE
# (n, m) : n(10) -(5)-> m : min(15, 10) -> NO UPDATE
# (n, q) : n(10) -(2)-> q : min(12, 12) -> NO UPDATE
# (n, r) : n(10) -(1)-> r : min(11, 9) -> NO UPDATE
# (o, h) : o(13) -(8)-> h : min(21, 6) -> NO UPDATE
# (o, l) : o(13) -(6)-> l : min(19, 7) -> NO UPDATE
# (o, m) : o(13) -(4)-> m : min(17, 10) -> NO UPDATE
# (o, p) : o(13) -(2)-> p : min(15, 12) -> NO UPDATE
# (o, s) : o(13) -(6)-> s : min(19, 14) -> NO UPDATE
# (p, m) : p(12) -(2)-> m : min(14, 10) -> NO UPDATE
# (p, o) : p(12) -(2)-> o : min(14, 13) -> NO UPDATE
# (p, q) : p(12) -(1)-> q : min(13, 12) -> NO UPDATE
# (p, s) : p(12) -(2)-> s : min(14, 14) -> NO UPDATE
# (p, t) : p(12) -(1)-> t : min(13, 13) -> NO UPDATE
# (q, n) : q(12) -(2)-> n : min(14, 10) -> NO UPDATE
# (q, p) : q(12) -(1)-> p : min(13, 12) -> NO UPDATE
# (q, r) : q(12) -(8)-> r : min(20, 9) -> NO UPDATE
# (q, t) : q(12) -(3)-> t : min(15, 13) -> NO UPDATE
# (r, k) : r(9) -(2)-> k : min(11, 7) -> NO UPDATE
# (r, n) : r(9) -(1)-> n : min(10, 10) -> NO UPDATE
# (r, q) : r(9) -(8)-> q : min(17, 12) -> NO UPDATE
# (r, t) : r(9) -(5)-> t : min(14, 13) -> NO UPDATE
# (s, o) : s(14) -(6)-> o : min(20, 13) -> NO UPDATE
# (s, p) : s(14) -(2)-> p : min(16, 12) -> NO UPDATE
# (s, z) : s(14) -(2)-> z : min(16, 16) -> NO UPDATE
# (t, p) : t(13) -(1)-> p : min(14, 12) -> NO UPDATE
# (t, q) : t(13) -(3)-> q : min(16, 12) -> NO UPDATE
# (t, r) : t(13) -(5)-> r : min(18, 9) -> NO UPDATE
# (t, z) : t(13) -(8)-> z : min(21, 16) -> NO UPDATE
# (z, s) : z(16) -(2)-> s : min(18, 14) -> NO UPDATE
# (z, t) : z(16) -(8)-> t : min(24, 13) -> NO UPDATE
#
# No updates in this iteration.
# => Algorithm converged early.
# => Stop before reaching V-1 iterations.
#
#
# ============================================================
# BEST PATHS FROM START:
# ============================================================
# a -> b: a(0) -(2)-> b(2)
# a -> c: a(0) -(4)-> c(4)
# a -> d: a(0) -(1)-> d(1)
# a -> e: a(0) -(2)-> b(2) -(1)-> e(3)
# a -> f: a(0) -(4)-> c(4) -(2)-> f(6)
# a -> g: a(0) -(1)-> d(1) -(4)-> g(5)
# a -> h: a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6)
# a -> i: a(0) -(4)-> c(4) -(2)-> f(6) -(2)-> i(8)
# a -> j: a(0) -(4)-> c(4) -(2)-> f(6) -(4)-> j(10)
# a -> k: a(0) -(1)-> d(1) -(4)-> g(5) -(2)-> k(7)
# a -> l: a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7)
# a -> m: a(0) -(4)-> c(4) -(2)-> f(6) -(2)-> i(8) -(2)-> m(10)
# a -> n: a(0) -(1)-> d(1) -(4)-> g(5) -(2)-> k(7) -(2)-> r(9) -(1)-> n(10)
# a -> o: a(0) -(2)-> b(2) -(1)-> e(3) -(3)-> h(6) -(1)-> l(7) -(6)-> o(13)
# a -> p: a(0) -(4)-> c(4) -(2)-> f(6) -(2)-> i(8) -(2)-> m(10) -(2)-> p(12)
# a -> q: a(0) -(1)-> d(1) -(4)-> g(5) -(2)-> k(7) -(2)-> r(9) -(1)-> n(10) -(2)-> q(12)
# a -> r: a(0) -(1)-> d(1) -(4)-> g(5) -(2)-> k(7) -(2)-> r(9)
# a -> s: a(0) -(4)-> c(4) -(2)-> f(6) -(2)-> i(8) -(2)-> m(10) -(2)-> p(12) -(2)-> s(14)
# a -> t: a(0) -(4)-> c(4) -(2)-> f(6) -(2)-> i(8) -(2)-> m(10) -(2)-> p(12) -(1)-> t(13)
# a -> z: a(0) -(4)-> c(4) -(2)-> f(6) -(2)-> i(8) -(2)-> m(10) -(2)-> p(12) -(2)-> s(14) -(2)-> z(16)
# Negative cycle: False

# %% [markdown]
# ## Floyd-Warshall

# %%
plot_floyd_warshall_trace(GRAPH_3)
# Out:
# Negative cycle: False
